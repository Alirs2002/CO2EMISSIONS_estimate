# %% [markdown]
# In this project, I want to create a regression model, that can evaluate, the amount of CO2 that comes out of the engine of a car.

# %% [markdown]
# lets import our libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# now,lets read our data from a csv file

# %%
data = pd.read_csv("../dataset/FuelConsumption.csv")

# %%
data
# Out:
#       MODELYEAR   MAKE       MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0          2014  ACURA         ILX         COMPACT         2.0          4
# 1          2014  ACURA         ILX         COMPACT         2.4          4
# 2          2014  ACURA  ILX HYBRID         COMPACT         1.5          4
# 3          2014  ACURA     MDX 4WD     SUV - SMALL         3.5          6
# 4          2014  ACURA     RDX AWD     SUV - SMALL         3.5          6
# ...         ...    ...         ...             ...         ...        ...
# 1062       2014  VOLVO    XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO    XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO    XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO    XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO    XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# ...

# %%
data.head(n=10)
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
# 5       2014  ACURA         RLX     MID-SIZE         3.5          6
# 6       2014  ACURA          TL     MID-SIZE         3.5          6
# 7       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 8       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 9       2014  ACURA         TSX      COMPACT         2.4          4
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# ...

# %%
data.tail()
# Out:
#       MODELYEAR   MAKE     MODEL    VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 1062       2014  VOLVO  XC60 AWD     SUV - SMALL         3.0          6
# 1063       2014  VOLVO  XC60 AWD     SUV - SMALL         3.2          6
# 1064       2014  VOLVO  XC70 AWD     SUV - SMALL         3.0          6
# 1065       2014  VOLVO  XC70 AWD     SUV - SMALL         3.2          6
# 1066       2014  VOLVO  XC90 AWD  SUV - STANDARD         3.2          6
#
#      TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 1062          AS6        X                  13.4                  9.8
# 1063          AS6        X                  13.2                  9.5
# 1064          AS6        X                  13.4                  9.8
# 1065          AS6        X                  12.9                  9.3
# 1066          AS6        X                  14.9                 10.2
#
#       FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# ...

# %%
data.shape
# Out:
# (1067, 13)

# %%
data.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG', 'CO2EMISSIONS'],
#       dtype='object')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
train,test = train_test_split(data , random_state=0)

# %%
x_train = train.drop(columns="CO2EMISSIONS")

# %%
y_train = train["CO2EMISSIONS"]

# %%
x_train
# Out:
#       MODELYEAR           MAKE                        MODEL  \
# 667        2014          LEXUS                     IS 350 C
# 37         2014           AUDI              ALLROAD QUATTRO
# 978        2014         TOYOTA               COROLLA MATRIX
# 158        2014       CADILLAC                          ATS
# 40         2014           AUDI                    Q5 HYBRID
# ...         ...            ...                          ...
# 1033       2014     VOLKSWAGEN  GOLF WAGON TDI CLEAN DIESEL
# 763        2014  MERCEDES-BENZ            ML 350 4MATIC FFV
# 835        2014         NISSAN                370Z ROADSTER
# 559        2014         JAGUAR             XJL SUPERCHARGED
# 684        2014        LINCOLN                      MKZ AWD
#
#                VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 667              SUBCOMPACT         3.5          6          AS6        Z
# 37    STATION WAGON - SMALL         2.0          4          AS8        Z
# ...

# %%
y_train
# Out:
# 667     244
# 37      242
# 978     196
# 158     207
# 40      212
#        ...
# 1033    186
# 763     256
# 835     269
# 559     306
# 684     262
# Name: CO2EMISSIONS, Length: 800, dtype: int64

# %%
x_train["fuel_consumption"] =  x_train["FUELCONSUMPTION_CITY"]+x_train["FUELCONSUMPTION_COMB"]+x_train["FUELCONSUMPTION_COMB_MPG"]+x_train["FUELCONSUMPTION_HWY"]

# %%
x_train["fuel_consumption"] = (x_train["fuel_consumption"]/4)

# %%
x_train
# Out:
#       MODELYEAR           MAKE                        MODEL  \
# 667        2014          LEXUS                     IS 350 C
# 37         2014           AUDI              ALLROAD QUATTRO
# 978        2014         TOYOTA               COROLLA MATRIX
# 158        2014       CADILLAC                          ATS
# 40         2014           AUDI                    Q5 HYBRID
# ...         ...            ...                          ...
# 1033       2014     VOLKSWAGEN  GOLF WAGON TDI CLEAN DIESEL
# 763        2014  MERCEDES-BENZ            ML 350 4MATIC FFV
# 835        2014         NISSAN                370Z ROADSTER
# 559        2014         JAGUAR             XJL SUPERCHARGED
# 684        2014        LINCOLN                      MKZ AWD
#
#                VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 667              SUBCOMPACT         3.5          6          AS6        Z
# 37    STATION WAGON - SMALL         2.0          4          AS8        Z
# ...

# %%
x_train = x_train.drop(columns=["FUELCONSUMPTION_CITY","FUELCONSUMPTION_COMB","FUELCONSUMPTION_COMB_MPG","FUELCONSUMPTION_HWY"])

# %%
x_train
# Out:
#       MODELYEAR           MAKE                        MODEL  \
# 667        2014          LEXUS                     IS 350 C
# 37         2014           AUDI              ALLROAD QUATTRO
# 978        2014         TOYOTA               COROLLA MATRIX
# 158        2014       CADILLAC                          ATS
# 40         2014           AUDI                    Q5 HYBRID
# ...         ...            ...                          ...
# 1033       2014     VOLKSWAGEN  GOLF WAGON TDI CLEAN DIESEL
# 763        2014  MERCEDES-BENZ            ML 350 4MATIC FFV
# 835        2014         NISSAN                370Z ROADSTER
# 559        2014         JAGUAR             XJL SUPERCHARGED
# 684        2014        LINCOLN                      MKZ AWD
#
#                VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 667              SUBCOMPACT         3.5          6          AS6        Z
# 37    STATION WAGON - SMALL         2.0          4          AS8        Z
# ...

# %% [markdown]
# at first, i just consider features,that i think are important,as i am interested in cars :))

# %%
y_train  =train["CO2EMISSIONS"]

# %%
type(y_train)
# Out:
# pandas.core.series.Series

# %%
x_train.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'fuel_consumption'],
#       dtype='object')

# %%
train_x = x_train[["ENGINESIZE","CYLINDERS","fuel_consumption"]]

# %%
train_x
# Out:
#       ENGINESIZE  CYLINDERS  fuel_consumption
# 667          3.5          6            14.600
# 37           2.0          4            14.525
# 978          1.8          4            14.600
# 158          2.5          4            14.425
# 40           2.0          4            14.600
# ...          ...        ...               ...
# 1033         2.0          4            15.350
# 763          3.5          6            16.400
# 835          3.7          6            14.700
# 559          5.0          8            15.075
# 684          3.7          6            14.700
#
# [800 rows x 3 columns]

# %%
train_x.shape
# Out:
# (800, 3)

# %%
lr = LinearRegression()
lr.fit(train_x,y_train)
# Out:
# LinearRegression()

# %%
print("accuracy score is :{}".format(lr.score(train_x,y_train)))

from sklearn.metrics import r2_score
# Out:
# accuracy score is :0.796175872754612

# %%
x_test = test.drop(columns=["CO2EMISSIONS"])

# %%
x_test
# Out:
#       MODELYEAR           MAKE                    MODEL    VEHICLECLASS  \
# 766        2014  MERCEDES-BENZ         ML 63 AMG 4MATIC  SUV - STANDARD
# 204        2014      CHEVROLET                  EQUINOX     SUV - SMALL
# 629        2014            KIA                 SPORTAGE     SUV - SMALL
# 897        2014        PORSCHE                   CAYMAN      TWO-SEATER
# 711        2014          MAZDA  MAZDA3 5-DOOR (i-ELOOP)        MID-SIZE
# ...         ...            ...                      ...             ...
# 511        2014        HYUNDAI       SANTA FE SPORT 4WD     SUV - SMALL
# 1021       2014     VOLKSWAGEN       BEETLE CONVERTIBLE      SUBCOMPACT
# 362        2014           FORD       EXPEDITION 4X4 FFV  SUV - STANDARD
# 963        2014         SUBARU         XV CROSSTREK AWD     SUV - SMALL
# 113        2014            BMW           ACTIVEHYBRID 3         COMPACT
#
#       ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# ...

# %%
y_test = test["CO2EMISSIONS"]

# %%
y_test.shape
# Out:
# (267,)

# %%
x_test.shape
# Out:
# (267, 12)

# %%
x_test.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'FUELCONSUMPTION_CITY',
#        'FUELCONSUMPTION_HWY', 'FUELCONSUMPTION_COMB',
#        'FUELCONSUMPTION_COMB_MPG'],
#       dtype='object')

# %%
x_test["fuel_consumption"] = x_test['FUELCONSUMPTION_CITY']+x_test["FUELCONSUMPTION_HWY"]+x_test["FUELCONSUMPTION_COMB"]+x_test["FUELCONSUMPTION_COMB_MPG"]
x_test["fuel_consumption"] = x_test["fuel_consumption"]/4

# %%
x_test["fuel_consumption"]
# Out:
# 766     16.050
# 204     14.475
# 629     14.425
# 897     14.575
# 711     15.150
#          ...
# 511     14.775
# 1021    14.425
# 362     19.275
# 963     14.600
# 113     14.650
# Name: fuel_consumption, Length: 267, dtype: float64

# %%
temp_x_test = x_test.drop(columns=["FUELCONSUMPTION_CITY","FUELCONSUMPTION_HWY","FUELCONSUMPTION_COMB","FUELCONSUMPTION_COMB_MPG"])

# %%
temp_x_test
# Out:
#       MODELYEAR           MAKE                    MODEL    VEHICLECLASS  \
# 766        2014  MERCEDES-BENZ         ML 63 AMG 4MATIC  SUV - STANDARD
# 204        2014      CHEVROLET                  EQUINOX     SUV - SMALL
# 629        2014            KIA                 SPORTAGE     SUV - SMALL
# 897        2014        PORSCHE                   CAYMAN      TWO-SEATER
# 711        2014          MAZDA  MAZDA3 5-DOOR (i-ELOOP)        MID-SIZE
# ...         ...            ...                      ...             ...
# 511        2014        HYUNDAI       SANTA FE SPORT 4WD     SUV - SMALL
# 1021       2014     VOLKSWAGEN       BEETLE CONVERTIBLE      SUBCOMPACT
# 362        2014           FORD       EXPEDITION 4X4 FFV  SUV - STANDARD
# 963        2014         SUBARU         XV CROSSTREK AWD     SUV - SMALL
# 113        2014            BMW           ACTIVEHYBRID 3         COMPACT
#
#       ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  fuel_consumption
# ...

# %%
test_x = temp_x_test[["ENGINESIZE","CYLINDERS","fuel_consumption"]]

# %%
from sklearn.metrics import r2_score

# %%
predicted = lr.predict(test_x)

# %%
accuracy = r2_score(y_test,predicted)
print(accuracy)
# Out:
# 0.7276711038738841

# %% [markdown]
# i am not sattisfied
# lets work more

# %%
type(new_x_train)
# Out:
# numpy.ndarray

# %%
new_x_train = np.asanyarray(train["ENGINESIZE"])
new_y_train  = np.asanyarray(train["CO2EMISSIONS"])

new_x_train = new_x_train.reshape(-1,1)



linear_r = LinearRegression()
linear_r.fit(new_x_train,new_y_train)
# Out:
# LinearRegression()

# %%
new_x_test = np.asanyarray(test["ENGINESIZE"])
new_y_test = np.asanyarray(test["CO2EMISSIONS"])

new_x_test = new_x_test.reshape(-1,1)

predicted2  = linear_r.predict(new_x_test)

# %%
accu = r2_score(new_y_test,predicted)
print(accu)
# Out:
# 0.7276711038738841

# %% [markdown]
# As we can see,it seems with simple linear regression,having the r2score of 72 percent,is like its maximum...now lets try encoding to see if we can improve the model's r2scre

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
train
# Out:
#       MODELYEAR           MAKE                        MODEL  \
# 667        2014          LEXUS                     IS 350 C
# 37         2014           AUDI              ALLROAD QUATTRO
# 978        2014         TOYOTA               COROLLA MATRIX
# 158        2014       CADILLAC                          ATS
# 40         2014           AUDI                    Q5 HYBRID
# ...         ...            ...                          ...
# 1033       2014     VOLKSWAGEN  GOLF WAGON TDI CLEAN DIESEL
# 763        2014  MERCEDES-BENZ            ML 350 4MATIC FFV
# 835        2014         NISSAN                370Z ROADSTER
# 559        2014         JAGUAR             XJL SUPERCHARGED
# 684        2014        LINCOLN                      MKZ AWD
#
#                VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 667              SUBCOMPACT         3.5          6          AS6        Z
# 37    STATION WAGON - SMALL         2.0          4          AS8        Z
# ...

# %%
test
# Out:
#       MODELYEAR           MAKE                    MODEL    VEHICLECLASS  \
# 766        2014  MERCEDES-BENZ         ML 63 AMG 4MATIC  SUV - STANDARD
# 204        2014      CHEVROLET                  EQUINOX     SUV - SMALL
# 629        2014            KIA                 SPORTAGE     SUV - SMALL
# 897        2014        PORSCHE                   CAYMAN      TWO-SEATER
# 711        2014          MAZDA  MAZDA3 5-DOOR (i-ELOOP)        MID-SIZE
# ...         ...            ...                      ...             ...
# 511        2014        HYUNDAI       SANTA FE SPORT 4WD     SUV - SMALL
# 1021       2014     VOLKSWAGEN       BEETLE CONVERTIBLE      SUBCOMPACT
# 362        2014           FORD       EXPEDITION 4X4 FFV  SUV - STANDARD
# 963        2014         SUBARU         XV CROSSTREK AWD     SUV - SMALL
# 113        2014            BMW           ACTIVEHYBRID 3         COMPACT
#
#       ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# ...

# %%
train["fuel_con"] = train["FUELCONSUMPTION_CITY"]+train["FUELCONSUMPTION_COMB"]+train["FUELCONSUMPTION_COMB_MPG"]+train["FUELCONSUMPTION_HWY"]

train["fuel_con"]  = train["fuel_con"]*4

# %%
train = train.drop(columns=["FUELCONSUMPTION_CITY","FUELCONSUMPTION_COMB","FUELCONSUMPTION_COMB_MPG","FUELCONSUMPTION_HWY"])

# %%
train
# Out:
#       MODELYEAR           MAKE                        MODEL  \
# 667        2014          LEXUS                     IS 350 C
# 37         2014           AUDI              ALLROAD QUATTRO
# 978        2014         TOYOTA               COROLLA MATRIX
# 158        2014       CADILLAC                          ATS
# 40         2014           AUDI                    Q5 HYBRID
# ...         ...            ...                          ...
# 1033       2014     VOLKSWAGEN  GOLF WAGON TDI CLEAN DIESEL
# 763        2014  MERCEDES-BENZ            ML 350 4MATIC FFV
# 835        2014         NISSAN                370Z ROADSTER
# 559        2014         JAGUAR             XJL SUPERCHARGED
# 684        2014        LINCOLN                      MKZ AWD
#
#                VEHICLECLASS  ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  \
# 667              SUBCOMPACT         3.5          6          AS6        Z
# 37    STATION WAGON - SMALL         2.0          4          AS8        Z
# ...

# %%
test["fuel_con"] = test["FUELCONSUMPTION_CITY"]+test["FUELCONSUMPTION_COMB"]+test["FUELCONSUMPTION_COMB_MPG"]+test["FUELCONSUMPTION_HWY"]

test["fuel_con"]  = test["fuel_con"]/4

# %%
test
# Out:
#       MODELYEAR           MAKE                    MODEL    VEHICLECLASS  \
# 766        2014  MERCEDES-BENZ         ML 63 AMG 4MATIC  SUV - STANDARD
# 204        2014      CHEVROLET                  EQUINOX     SUV - SMALL
# 629        2014            KIA                 SPORTAGE     SUV - SMALL
# 897        2014        PORSCHE                   CAYMAN      TWO-SEATER
# 711        2014          MAZDA  MAZDA3 5-DOOR (i-ELOOP)        MID-SIZE
# ...         ...            ...                      ...             ...
# 511        2014        HYUNDAI       SANTA FE SPORT 4WD     SUV - SMALL
# 1021       2014     VOLKSWAGEN       BEETLE CONVERTIBLE      SUBCOMPACT
# 362        2014           FORD       EXPEDITION 4X4 FFV  SUV - STANDARD
# 963        2014         SUBARU         XV CROSSTREK AWD     SUV - SMALL
# 113        2014            BMW           ACTIVEHYBRID 3         COMPACT
#
#       ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  \
# ...

# %%
train_feat = train.drop(columns="CO2EMISSIONS")
train_target = train["CO2EMISSIONS"]

test_feat = test.drop(columns="CO2EMISSIONS")
test_target  = test["CO2EMISSIONS"]

# %%
train_feat.columns
# Out:
# Index(['MODELYEAR', 'MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'fuel_con'],
#       dtype='object')

# %% [markdown]
# since all of the values of model column is 2014,it is not a necessary feature,so we will drop it in the next cell

# %%
train_feat = train_feat.drop(columns="MODELYEAR")

# %%
train_feat.columns
# Out:
# Index(['MAKE', 'MODEL', 'VEHICLECLASS', 'ENGINESIZE', 'CYLINDERS',
#        'TRANSMISSION', 'FUELTYPE', 'fuel_con'],
#       dtype='object')

# %%
train_feat
# Out:
#                MAKE                        MODEL           VEHICLECLASS  \
# 667           LEXUS                     IS 350 C             SUBCOMPACT
# 37             AUDI              ALLROAD QUATTRO  STATION WAGON - SMALL
# 978          TOYOTA               COROLLA MATRIX  STATION WAGON - SMALL
# 158        CADILLAC                          ATS                COMPACT
# 40             AUDI                    Q5 HYBRID            SUV - SMALL
# ...             ...                          ...                    ...
# 1033     VOLKSWAGEN  GOLF WAGON TDI CLEAN DIESEL  STATION WAGON - SMALL
# 763   MERCEDES-BENZ            ML 350 4MATIC FFV         SUV - STANDARD
# 835          NISSAN                370Z ROADSTER             TWO-SEATER
# 559          JAGUAR             XJL SUPERCHARGED              FULL-SIZE
# 684         LINCOLN                      MKZ AWD               MID-SIZE
#
#       ENGINESIZE  CYLINDERS TRANSMISSION FUELTYPE  fuel_con
# ...
